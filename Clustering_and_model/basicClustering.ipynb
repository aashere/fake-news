# %%
import pandas as pd
import numpy as np
import nltk
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
nltk.download('punkt')
nltk.download('wordnet')
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import re
lemmatizer = WordNetLemmatizer()

# %%
stop_word_dic={}

with open('sample_data/extra_stop.txt','r') as file:
   
    # reading each line    
    for line in file:
   
        # reading each word        
        for word in line.split():
   
            # displaying the words           
            stop_word_dic[word]=word
with open('sample_data/stop_words_english.txt','r') as file:
   
    # reading each line    
    for line in file:
   
        # reading each word        
        for word in line.split():
   
            # displaying the words           
            stop_word_dic[word]=word



closed_class_stop_words = ['a', 'the', 'an', 'and', 'or', 'but', 'about', 'above', 'after', 'along', 'amid', 'among', \
                           'as', 'at', 'by', 'for', 'from', 'in', 'into', 'like', 'minus', 'near', 'of', 'off', 'on', \
                           'onto', 'out', 'over', 'past', 'per', 'plus', 'since', 'till', 'to', 'under', 'until', 'up', \
                           'via', 'vs', 'with', 'that', 'can', 'cannot', 'could', 'may', 'might', 'must', \
                           'need', 'ought', 'shall', 'should', 'will', 'would', 'have', 'had', 'has', 'having', 'be', \
                           'is', 'am', 'are', 'was', 'were', 'being', 'been', 'get', 'gets', 'got', 'gotten', \
                           'getting', 'seem', 'seeming', 'seems', 'seemed', \
                           'enough', 'both', 'all', 'your' 'those', 'this', 'these', \
                           'their', 'the', 'that', 'some', 'our', 'no', 'neither', 'my', \
                           'its', 'his' 'her', 'every', 'either', 'each', 'any', 'another', \
                           'an', 'a', 'just', 'mere', 'such', 'merely' 'right', 'no', 'not', \
                           'only', 'sheer', 'even', 'especially', 'namely', 'as', 'more', \
                           'most', 'less' 'least', 'so', 'enough', 'too', 'pretty', 'quite', \
                           'rather', 'somewhat', 'sufficiently' 'same', 'different', 'such', \
                           'when', 'why', 'where', 'how', 'what', 'who', 'whom', 'which', \
                           'whether', 'why', 'whose', 'if', 'anybody', 'anyone', 'anyplace', \
                           'anything', 'anytime' 'anywhere', 'everybody', 'everyday', \
                           'everyone', 'everyplace', 'everything' 'everywhere', 'whatever', \
                           'whenever', 'whereever', 'whichever', 'whoever', 'whomever' 'he', \
                           'him', 'his', 'her', 'she', 'it', 'they', 'them', 'its', 'their', 'theirs', \
                           'you', 'your', 'yours', 'me', 'my', 'mine', 'I', 'we', 'us', 'much', 'and/or',"wa","ha",",","n't" ,"”" ,"“" ,"’"
                           ]

# %%
df_true= pd.read_csv("sample_data/true_news.csv")
df_fake=pd.read_csv("sample_data/fake_n.csv")
df_pants=pd.read_csv("sample_data/pants_on_fire.csv")

# %% [markdown]
# # New Section

# %%
def make_dic():
  for stop in closed_class_stop_words:
    stop_word_dic[stop]=stop           
make_dic()  
def clean_me(string):
  return remove_stop_words(word_tokenize(string))
def remove_stop_words(text):
  result=[]
  for word in text:
    word=word.lower()
    word=lemmatizer.lemmatize(word)
    if word in stop_word_dic:
      continue
    else:
      result.append(word)
  return result

# %%
def clean_data_frameTF_IDF(df,AP,col="Statement"):
  text=df[col]
  clean_text=[]
  id=[]
  Link=[]
  df_clean=pd.DataFrame()
  for index, row in df.iterrows():
    text=row[col]
    res=" ".join(clean_me(text))
    clean_text.append(res)
    if col =="Statement":
      id.append(row['Date'])
      Link.append(row['Link'])
  if(AP):
      for index, row in df_pants.iterrows():
        text=row[col]
        res=" ".join(clean_me(text))
        clean_text.append(res)
        if col =="Statement":
          id.append(row['Date'])
          Link.append(row['Link'])

  if col =="Statement":
    #, "link":Link
    return pd.DataFrame({'Date': id, 'Clean_text': clean_text}),clean_text
  else:
    return pd.DataFrame({'Clean_tweet': clean_text})

df_clean_true=clean_data_frameTF_IDF(df_true,False)
df_clean_false=clean_data_frameTF_IDF(df_fake,True)

# %%
def clean_data_frame(df,AP,col="Statement"):
  text=df[col]
  clean_text=[]
  id=[]
  Link=[]
  df_clean=pd.DataFrame()
  for index, row in df.iterrows():
    text=row[col]
  #text = re.sub(r'@.+', text)
    res=clean_me(text)
    clean_text.append(res)
    if col =="Statement":
      id.append(row['Date'])
      Link.append(row['Link'])
  
  #clean_text.append(clean_me(row[' text']))
  if(AP):
    for index, row in df_pants.iterrows():
      text=row[col]
    #text = re.sub(r'@.+', text)
      res=clean_me(text)
      clean_text.append(res)
      if col =="Statement":
        id.append(row['Date'])
        Link.append(row['Link'])

  if col =="Statement":
    return pd.DataFrame({'Date': id, 'Clean_text': clean_text, "link":Link})
  else:
    return pd.DataFrame({'Clean_tweet': clean_text})

df_clean_true_list=clean_data_frame(df_true,False)
df_clean_false_list=clean_data_frame(df_fake,True)

# %%
corpus=df_clean_false[1]
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(corpus)

# %%
from sklearn.decomposition import TruncatedSVD
from scipy.sparse import csr_matrix
np.random.seed(0)
X = csr_matrix(X)
svd = TruncatedSVD(n_components=1000, n_iter=10, random_state=42)
y=svd.fit_transform(X)

# %%
from sklearn.cluster import DBSCAN
clustering = DBSCAN(eps=0.5, min_samples=5, metric='cosine').fit(y)

# %%
from numpy.lib.function_base import disp
df=df_clean_false[0]
unique, counts = np.unique(clustering.labels_, return_counts=True)
counts_cluster=(dict(zip(unique, counts)))
sorted_dict = {}
sorted_keys = sorted(counts_cluster, key=counts_cluster.get, reverse=True) 
for w in sorted_keys:
    sorted_dict[w] = counts_cluster[w]
pd.options.display.max_colwidth = 200
print(sorted_dict)
breaker=0
str_result=[]
d=df
for i,x in enumerate(clustering.labels_):
  if(x==12):
    d=df.iloc[[i]]
    str_result.append(df_clean_false_list.iloc[i]['Clean_text'])
    display(d)
    Sep = d.loc[(d['Clean_text'].str.contains('acc'))]
    if(len(Sep["Clean_text"])!=0):
      display(Sep)
    breaker+=1
    if(breaker>300):
      break
print("printing")
print(str_result)
# Out:
# {-1: 4498, 1: 2498, 4: 59, 12: 41, 5: 30, 30: 23, 42: 23, 24: 20, 19: 19, 56: 18, 74: 18, 16: 17, 9: 16, 39: 16, 72: 16, 20: 15, 65: 15, 66: 15, 26: 14, 15: 13, 2: 12, 13: 12, 14: 12, 58: 12, 77: 12, 114: 12, 11: 11, 34: 11, 51: 11, 63: 11, 70: 11, 3: 10, 6: 10, 18: 10, 27: 10, 49: 10, 69: 10, 80: 10, 88: 9, 32: 8, 48: 8, 59: 8, 76: 8, 78: 8, 94: 8, 103: 8, 107: 8, 28: 7, 35: 7, 40: 7, 75: 7, 82: 7, 90: 7, 98: 7, 0: 6, 17: 6, 25: 6, 31: 6, 37: 6, 41: 6, 43: 6, 50: 6, 53: 6, 55: 6, 60: 6, 62: 6, 68: 6, 71: 6, 73: 6, 86: 6, 89: 6, 106: 6, 116: 6, 117: 6, 119: 6, 7: 5, 8: 5, 10: 5, 29: 5, 33: 5, 36: 5, 38: 5, 44: 5, 45: 5, 46: 5, 52: 5, 54: 5, 57: 5, 61: 5, 64: 5, 67: 5, 79: 5, 81: 5, 84: 5, 85: 5, 87: 5, 91: 5, 93: 5, 95: 5, 97: 5, 99: 5, 101: 5, 102: 5, 104: 5, 105: 5, 109: 5, 111: 5, 118: 5, 21: 4, 22: 4, 47: 4, 83: 4, 92: 4, 100: 4, 108: 4, 112: 4, 113: 4, 115: 4, 120: 4, 121: 4, 23: 3, 96: 3, 110: 3}
#                   Date                                   Clean_text
# 269  November 10, 2021  trump cut social security benefit 3 billion
#                  Date  \
# 434  October 20, 2021
#
#                                                                        Clean_text
# 434  don comply covid-19 vaccination social security disability won receive money
#                  Date  \
# 434  October 20, 2021
#
#                                                                        Clean_text
# 434  don comply covid-19 vaccination social security disability won receive money
#                Date  \
# 1853  April 5, 2020
#
#                                                        Clean_text
# 1853  italy thrown money street clear message money health danger
#                    Date  \
# 1966  December 27, 2019
#
#                                                     Clean_text
# 1966  social security check referred ‘ federal benefit payment
#                Date  \
# 2029  July 13, 2018
#
#                                                                                                                                                   Clean_text
# 2029  democratic party social security independent ‘ trust fund general fund congress spend eliminated income tax deduction social security fica withholding
#                 Date  \
# 2737  April 29, 2018
#
#                                                                                      Clean_text
# 2737  president donald trump budget threatened cut 2 trillion social security medicare medicaid
#                 Date  \
# 2758  March 29, 2018
#
#                                                           Clean_text
# 2758  republican congress plotting medicare medicaid social security
#                Date  \
# 2764  April 2, 2018
#
#                                                                  Clean_text
# 2764  fool worse money losing post office money amazon lose fortune changed
#                 Date                     Clean_text
# 2770  March 12, 2018  housing authority money nycha
#                   Date                                 Clean_text
# 3070  December 9, 2016  republican cut social security 50 percent
#                     Date                             Clean_text
# 3157  September 12, 2016  donald j.trump foundation money money
#                    Date                Clean_text
# 3401  November 10, 2015  welder money philosopher
#                     Date                             Clean_text
# 3662  September 18, 2014  social security medicare ponzi scheme
#                    Date  \
# 3678  September 3, 2014
#
#                                                       Clean_text
# 3678  mark pryor voted social security benefit illegal immigrant
#                     Date  \
# 3951  September 25, 2013
#
#                                                                   Clean_text
# 3951  texas republican abolishing social security abolishing v.a health care
#                Date  \
# 4003  June 19, 2013
#
#                                                                           Clean_text
# 4003  70 percent federal spending social security medicare medicaid fiscal year 2014
#                  Date  \
# 4134  October 1, 2012
#
#                                                                          Clean_text
# 4134  u.s. senate candidate tommy thompson support plan privatizing social security
#                    Date  \
# 4145  September 3, 2012
#
#                                                                                                           Clean_text
# 4145  … agreement mexican citizen eligible social security benefit stronger claim benefit protection cut u.s citizen
#                    Date  \
# 4196  September 6, 2012
#
#                                                                Clean_text
# 4196  social security medicare medicaid created republican stood sideline
#               Date  \
# 4291  June 8, 2012
#
#                                                           Clean_text
# 4291  koch brother money scott walker total money raised tom barrett
#                   Date                                 Clean_text
# 4528  October 26, 2011  sixty-percent retiree don social security
#                  Date                   Clean_text
# 4568  October 1, 2011  today social security broke
#                     Date                    Clean_text
# 4591  September 12, 2011  social security ponzi scheme
#                Date             Clean_text
# 4629  July 24, 2011  money social security
#                    Date       Clean_text
# 4813  February 21, 2011  broke don money
#                   Date                    Clean_text
# 4925  November 8, 2010  social security ponzi scheme
#                   Date  \
# 4938  October 29, 2010
#
#                                                         Clean_text
# 4938  rus feingold voted social security benefit illegal immigrant
#                  Date  \
# 4967  October 6, 2010
#
#                                                                                        Clean_text
# 4967  offered plan social security supported robert reich secretary labor previous administration
#                    Date                    Clean_text
# 4997  February 24, 2010  social security ponzi scheme
#                     Date  \
# 5019  September 13, 2010
#
#                                                                            Clean_text
# 5019  allen west called social security ponzi scheme country sound footing destroying
#                 Date  \
# 5092  June 11, 2010:
#
#                                                       Clean_text
# 5092  social security told money year borrowing general treasury
#                    Date                  Clean_text
# 5245  September 9, 2009  preventive care save money
#                  Date  \
# 5249  August 25, 2009
#
#                                                                                                      Clean_text
# 5249  great program american history social security republican medicare republican support vote realized board
#                 Date  \
# 5350  April 14, 2008
#
#                                                             Clean_text
# 5350  promising year administration push privatization social security
#               Date                                                  Clean_text
# 6023  May 10, 2020  democrat introduce ‘ euthanize senior save social security
#                     Date  \
# 7269  September 19, 2014
#
#                                                       Clean_text
# 7269  mary landrieu voted fund benefit illegal immigrant veteran
#                    Date  \
# 7820  November 13, 2010
#
#                                                                                                         Clean_text
# 7820  talk congress basically confiscating private 401 ira plan rolling social security strengthen social security
#                    Date  \
# 7821  November 22, 2010
#
#                                                            Clean_text
# 7821  town wilmington ohio hasn money government don money government
#                    Date  \
# 7872  September 1, 2010
#
#                                                                  Clean_text
# 7872  ganley elected ‘ cut dickens social security medicare veteran benefit
#                   Date                                            Clean_text
# 7945  February 3, 2010  congressman mccollum voted dismantle social security
#                Date  \
# 7982  July 14, 2009
#
#                                                           Clean_text
# 7982  senate voted week illegal alien access social security benefit
#                Date  \
# 7982  July 14, 2009
#
#                                                           Clean_text
# 7982  senate voted week illegal alien access social security benefit
# printing
# [['trump', 'cut', 'social', 'security', 'benefit', '3', 'billion'], ['don', 'comply', 'covid-19', 'vaccination', 'social', 'security', 'disability', 'won', 'receive', 'money'], ['italy', 'thrown', 'money', 'street', 'clear', 'message', 'money', 'health', 'danger'], ['social', 'security', 'check', 'referred', '‘', 'federal', 'benefit', 'payment'], ['democratic', 'party', 'social', 'security', 'independent', '‘', 'trust', 'fund', 'general', 'fund', 'congress', 'spend', 'eliminated', 'income', 'tax', 'deduction', 'social', 'security', 'fica', 'withholding'], ['president', 'donald', 'trump', 'budget', 'threatened', 'cut', '2', 'trillion', 'social', 'security', 'medicare', 'medicaid'], ['republican', 'congress', 'plotting', 'medicare', 'medicaid', 'social', 'security'], ['fool', 'worse', 'money', 'losing', 'post', 'office', 'money', 'amazon', 'lose', 'fortune', 'changed'], ['housing', 'authority', 'money', 'nycha'], ['republican', 'cut', 'social', 'security', '50', 'percent'], ['donald', 'j.trump', 'foundation', 'money', 'money'], ['welder', 'money', 'philosopher'], ['social', 'security', 'medicare', 'ponzi', 'scheme'], ['mark', 'pryor', 'voted', 'social', 'security', 'benefit', 'illegal', 'immigrant'], ['texas', 'republican', 'abolishing', 'social', 'security', 'abolishing', 'v.a', 'health', 'care'], ['70', 'percent', 'federal', 'spending', 'social', 'security', 'medicare', 'medicaid', 'fiscal', 'year', '2014'], ['u.s.', 'senate', 'candidate', 'tommy', 'thompson', 'support', 'plan', 'privatizing', 'social', 'security'], ['…', 'agreement', 'mexican', 'citizen', 'eligible', 'social', 'security', 'benefit', 'stronger', 'claim', 'benefit', 'protection', 'cut', 'u.s', 'citizen'], ['social', 'security', 'medicare', 'medicaid', 'created', 'republican', 'stood', 'sideline'], ['koch', 'brother', 'money', 'scott', 'walker', 'total', 'money', 'raised', 'tom', 'barrett'], ['sixty-percent', 'retiree', 'don', 'social', 'security'], ['today', 'social', 'security', 'broke'], ['social', 'security', 'ponzi', 'scheme'], ['money', 'social', 'security'], ['broke', 'don', 'money'], ['social', 'security', 'ponzi', 'scheme'], ['rus', 'feingold', 'voted', 'social', 'security', 'benefit', 'illegal', 'immigrant'], ['offered', 'plan', 'social', 'security', 'supported', 'robert', 'reich', 'secretary', 'labor', 'previous', 'administration'], ['social', 'security', 'ponzi', 'scheme'], ['allen', 'west', 'called', 'social', 'security', 'ponzi', 'scheme', 'country', 'sound', 'footing', 'destroying'], ['social', 'security', 'told', 'money', 'year', 'borrowing', 'general', 'treasury'], ['preventive', 'care', 'save', 'money'], ['great', 'program', 'american', 'history', 'social', 'security', 'republican', 'medicare', 'republican', 'support', 'vote', 'realized', 'board'], ['promising', 'year', 'administration', 'push', 'privatization', 'social', 'security'], ['democrat', 'introduce', '‘', 'euthanize', 'senior', 'save', 'social', 'security'], ['mary', 'landrieu', 'voted', 'fund', 'benefit', 'illegal', 'immigrant', 'veteran'], ['talk', 'congress', 'basically', 'confiscating', 'private', '401', 'ira', 'plan', 'rolling', 'social', 'security', 'strengthen', 'social', 'security'], ['town', 'wilmington', 'ohio', 'hasn', 'money', 'government', 'don', 'money', 'government'], ['ganley', 'elected', '‘', 'cut', 'dickens', 'social', 'security', 'medicare', 'veteran', 'benefit'], ['congressman', 'mccollum', 'voted', 'dismantle', 'social', 'security'], ['senate', 'voted', 'week', 'illegal', 'alien', 'access', 'social', 'security', 'benefit']]

# %%
from collections import Counter
bag={}

res=" "
for index in str_result:
  
  for el in index:

    if(el in bag):
      bag[el]+=1
    else:
      bag[el]=1
    res=res+" "+str(el)
print(res)
words=res.split(' ')
bigrams = zip(words, words[1:])
bg=[]
for w1 in bigrams:
  bg.append(w1[0]+"_"+w1[1])
counts = Counter(bg)
resy={}
sorted_keys2 = sorted(bag, key=bag.get, reverse=True) 
for w in sorted_keys2:
    resy[w] = bag[w]
sorted_dict1={}
sorted_keys1 = sorted(counts, key=counts.get, reverse=True) 
for w in sorted_keys1:
    sorted_dict1[w] = counts[w]
print(resy)
print(sorted_dict1)
# Out:
#   trump cut social security benefit 3 billion don comply covid-19 vaccination social security disability won receive money italy thrown money street clear message money health danger social security check referred ‘ federal benefit payment democratic party social security independent ‘ trust fund general fund congress spend eliminated income tax deduction social security fica withholding president donald trump budget threatened cut 2 trillion social security medicare medicaid republican congress plotting medicare medicaid social security fool worse money losing post office money amazon lose fortune changed housing authority money nycha republican cut social security 50 percent donald j.trump foundation money money welder money philosopher social security medicare ponzi scheme mark pryor voted social security benefit illegal immigrant texas republican abolishing social security abolishing v.a health care 70 percent federal spending social security medicare medicaid fiscal year 2014 u.s. senate candidate tommy thompson support plan privatizing social security … agreement mexican citizen eligible social security benefit stronger claim benefit protection cut u.s citizen social security medicare medicaid created republican stood sideline koch brother money scott walker total money raised tom barrett sixty-percent retiree don social security today social security broke social security ponzi scheme money social security broke don money social security ponzi scheme rus feingold voted social security benefit illegal immigrant offered plan social security supported robert reich secretary labor previous administration social security ponzi scheme allen west called social security ponzi scheme country sound footing destroying social security told money year borrowing general treasury preventive care save money great program american history social security republican medicare republican support vote realized board promising year administration push privatization social security democrat introduce ‘ euthanize senior save social security mary landrieu voted fund benefit illegal immigrant veteran talk congress basically confiscating private 401 ira plan rolling social security strengthen social security town wilmington ohio hasn money government don money government ganley elected ‘ cut dickens social security medicare veteran benefit congressman mccollum voted dismantle social security senate voted week illegal alien access social security benefit
# {'social': 33, 'security': 33, 'money': 17, 'benefit': 9, 'medicare': 7, 'republican': 6, 'cut': 5, 'ponzi': 5, 'scheme': 5, 'voted': 5, 'don': 4, '‘': 4, 'medicaid': 4, 'illegal': 4, 'fund': 3, 'congress': 3, 'immigrant': 3, 'year': 3, 'plan': 3, 'trump': 2, 'health': 2, 'federal': 2, 'general': 2, 'donald': 2, 'percent': 2, 'abolishing': 2, 'care': 2, 'senate': 2, 'support': 2, 'citizen': 2, 'broke': 2, 'administration': 2, 'save': 2, 'veteran': 2, 'government': 2, '3': 1, 'billion': 1, 'comply': 1, 'covid-19': 1, 'vaccination': 1, 'disability': 1, 'won': 1, 'receive': 1, 'italy': 1, 'thrown': 1, 'street': 1, 'clear': 1, 'message': 1, 'danger': 1, 'check': 1, 'referred': 1, 'payment': 1, 'democratic': 1, 'party': 1, 'independent': 1, 'trust': 1, 'spend': 1, 'eliminated': 1, 'income': 1, 'tax': 1, 'deduction': 1, 'fica': 1, 'withholding': 1, 'president': 1, 'budget': 1, 'threatened': 1, '2': 1, 'trillion': 1, 'plotting': 1, 'fool': 1, 'worse': 1, 'losing': 1, 'post': 1, 'office': 1, 'amazon': 1, 'lose': 1, 'fortune': 1, 'changed': 1, 'housing': 1, 'authority': 1, 'nycha': 1, '50': 1, 'j.trump': 1, 'foundation': 1, 'welder': 1, 'philosopher': 1, 'mark': 1, 'pryor': 1, 'texas': 1, 'v.a': 1, '70': 1, 'spending': 1, 'fiscal': 1, '2014': 1, 'u.s.': 1, 'candidate': 1, 'tommy': 1, 'thompson': 1, 'privatizing': 1, '…': 1, 'agreement': 1, 'mexican': 1, 'eligible': 1, 'stronger': 1, 'claim': 1, 'protection': 1, 'u.s': 1, 'created': 1, 'stood': 1, 'sideline': 1, 'koch': 1, 'brother': 1, 'scott': 1, 'walker': 1, 'total': 1, 'raised': 1, 'tom': 1, 'barrett': 1, 'sixty-percent': 1, 'retiree': 1, 'today': 1, 'rus': 1, 'feingold': 1, 'offered': 1, 'supported': 1, 'robert': 1, 'reich': 1, 'secretary': 1, 'labor': 1, 'previous': 1, 'allen': 1, 'west': 1, 'called': 1, 'country': 1, 'sound': 1, 'footing': 1, 'destroying': 1, 'told': 1, 'borrowing': 1, 'treasury': 1, 'preventive': 1, 'great': 1, 'program': 1, 'american': 1, 'history': 1, 'vote': 1, 'realized': 1, 'board': 1, 'promising': 1, 'push': 1, 'privatization': 1, 'democrat': 1, 'introduce': 1, 'euthanize': 1, 'senior': 1, 'mary': 1, 'landrieu': 1, 'talk': 1, 'basically': 1, 'confiscating': 1, 'private': 1, '401': 1, 'ira': 1, 'rolling': 1, 'strengthen': 1, 'town': 1, 'wilmington': 1, 'ohio': 1, 'hasn': 1, 'ganley': 1, 'elected': 1, 'dickens': 1, 'congressman': 1, 'mccollum': 1, 'dismantle': 1, 'week': 1, 'alien': 1, 'access': 1}
# {'social_security': 33, 'security_benefit': 5, 'security_medicare': 5, 'ponzi_scheme': 5, 'medicare_medicaid': 4, 'security_ponzi': 4, 'benefit_illegal': 3, 'illegal_immigrant': 3, 'cut_social': 2, 'voted_social': 2, 'security_broke': 2, 'money_social': 2, 'don_money': 2, 'money_government': 2, '_': 1, '_trump': 1, 'trump_cut': 1, 'benefit_3': 1, '3_billion': 1, 'billion_don': 1, 'don_comply': 1, 'comply_covid-19': 1, 'covid-19_vaccination': 1, 'vaccination_social': 1, 'security_disability': 1, 'disability_won': 1, 'won_receive': 1, 'receive_money': 1, 'money_italy': 1, 'italy_thrown': 1, 'thrown_money': 1, 'money_street': 1, 'street_clear': 1, 'clear_message': 1, 'message_money': 1, 'money_health': 1, 'health_danger': 1, 'danger_social': 1, 'security_check': 1, 'check_referred': 1, 'referred_‘': 1, '‘_federal': 1, 'federal_benefit': 1, 'benefit_payment': 1, 'payment_democratic': 1, 'democratic_party': 1, 'party_social': 1, 'security_independent': 1, 'independent_‘': 1, '‘_trust': 1, 'trust_fund': 1, 'fund_general': 1, 'general_fund': 1, 'fund_congress': 1, 'congress_spend': 1, 'spend_eliminated': 1, 'eliminated_income': 1, 'income_tax': 1, 'tax_deduction': 1, 'deduction_social': 1, 'security_fica': 1, 'fica_withholding': 1, 'withholding_president': 1, 'president_donald': 1, 'donald_trump': 1, 'trump_budget': 1, 'budget_threatened': 1, 'threatened_cut': 1, 'cut_2': 1, '2_trillion': 1, 'trillion_social': 1, 'medicaid_republican': 1, 'republican_congress': 1, 'congress_plotting': 1, 'plotting_medicare': 1, 'medicaid_social': 1, 'security_fool': 1, 'fool_worse': 1, 'worse_money': 1, 'money_losing': 1, 'losing_post': 1, 'post_office': 1, 'office_money': 1, 'money_amazon': 1, 'amazon_lose': 1, 'lose_fortune': 1, 'fortune_changed': 1, 'changed_housing': 1, 'housing_authority': 1, 'authority_money': 1, 'money_nycha': 1, 'nycha_republican': 1, 'republican_cut': 1, 'security_50': 1, '50_percent': 1, 'percent_donald': 1, 'donald_j.trump': 1, 'j.trump_foundation': 1, 'foundation_money': 1, 'money_money': 1, 'money_welder': 1, 'welder_money': 1, 'money_philosopher': 1, 'philosopher_social': 1, 'medicare_ponzi': 1, 'scheme_mark': 1, 'mark_pryor': 1, 'pryor_voted': 1, 'immigrant_texas': 1, 'texas_republican': 1, 'republican_abolishing': 1, 'abolishing_social': 1, 'security_abolishing': 1, 'abolishing_v.a': 1, 'v.a_health': 1, 'health_care': 1, 'care_70': 1, '70_percent': 1, 'percent_federal': 1, 'federal_spending': 1, 'spending_social': 1, 'medicaid_fiscal': 1, 'fiscal_year': 1, 'year_2014': 1, '2014_u.s.': 1, 'u.s._senate': 1, 'senate_candidate': 1, 'candidate_tommy': 1, 'tommy_thompson': 1, 'thompson_support': 1, 'support_plan': 1, 'plan_privatizing': 1, 'privatizing_social': 1, 'security_…': 1, '…_agreement': 1, 'agreement_mexican': 1, 'mexican_citizen': 1, 'citizen_eligible': 1, 'eligible_social': 1, 'benefit_stronger': 1, 'stronger_claim': 1, 'claim_benefit': 1, 'benefit_protection': 1, 'protection_cut': 1, 'cut_u.s': 1, 'u.s_citizen': 1, 'citizen_social': 1, 'medicaid_created': 1, 'created_republican': 1, 'republican_stood': 1, 'stood_sideline': 1, 'sideline_koch': 1, 'koch_brother': 1, 'brother_money': 1, 'money_scott': 1, 'scott_walker': 1, 'walker_total': 1, 'total_money': 1, 'money_raised': 1, 'raised_tom': 1, 'tom_barrett': 1, 'barrett_sixty-percent': 1, 'sixty-percent_retiree': 1, 'retiree_don': 1, 'don_social': 1, 'security_today': 1, 'today_social': 1, 'broke_social': 1, 'scheme_money': 1, 'broke_don': 1, 'scheme_rus': 1, 'rus_feingold': 1, 'feingold_voted': 1, 'immigrant_offered': 1, 'offered_plan': 1, 'plan_social': 1, 'security_supported': 1, 'supported_robert': 1, 'robert_reich': 1, 'reich_secretary': 1, 'secretary_labor': 1, 'labor_previous': 1, 'previous_administration': 1, 'administration_social': 1, 'scheme_allen': 1, 'allen_west': 1, 'west_called': 1, 'called_social': 1, 'scheme_country': 1, 'country_sound': 1, 'sound_footing': 1, 'footing_destroying': 1, 'destroying_social': 1, 'security_told': 1, 'told_money': 1, 'm ...

# %%
counts
